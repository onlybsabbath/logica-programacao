# %% [markdown]
# # Documentação
# ## Subtítulo

# %%
print('Olá Mundo')
# Out:
# Olá Mundo

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2

# %%
3
# Out:
# 3

# %%
4
# Out:
# 4

# %%
5
# Out:
# 5

# %%
6
# Out:
# 6
